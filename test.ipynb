# %% [markdown]
# ## test1
# the result shows that different combination between preprocessor and model yields different metrics.
# The KBinsDiscretizer preprocessor with GradientBoostingClassifier relatively low metrics in general, in wine dataset outperform other combinations.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings

from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    AdaBoostClassifier,
)
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import (
    KBinsDiscretizer,
    MinMaxScaler,
    StandardScaler,
    RobustScaler,
    QuantileTransformer,
)
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 10)
pd.set_option("display.max_rows", 10)
pd.set_option("display.width", 1000)

# https://www.notion.so/cheaper01flagon/Machine-Learning-final-project-7fbacb61a9c14215bb6ddc641c32cfae?pvs=4

plt.style.use("ggplot")
plt.rcParams["figure.figsize"] = (16, 9)
plt.rcParams["font.size"] = 14
plt.rcParams["axes.labelcolor"] = "k"
plt.rcParams["axes.edgecolor"] = "k"
plt.rcParams["xtick.color"] = "k"
plt.rcParams["ytick.color"] = "k"
plt.rcParams["axes.facecolor"] = "white"
plt.rcParams["figure.facecolor"] = "white"
plt.rcParams["axes.grid"] = True


iris = sns.load_dataset("iris")

data, target = iris.loc[:, iris.columns != "species"], iris.loc[:, "species"]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    data, target, test_size=0.1, random_state=0, shuffle=True
)

pre_processors = [
    StandardScaler(),
    MinMaxScaler(),
    KBinsDiscretizer(),
    RobustScaler(),
    QuantileTransformer(),
]

StandardScaler_params = {
    "with_mean": [True, False],
    "with_std": [True, False],
}
MinMaxScaler_params = {
    "feature_range": [(0, 1), (-1, 1)],
}
KBinsDiscretizer_params = {
    "n_bins": [3, 5, 10],
    "encode": ["ordinal", "onehot", "onehot-dense"],
    "strategy": ["uniform", "quantile", "kmeans"],
}
RobustScaler_params = {
    "with_centering": [True, False],
    "with_scaling": [True, False],
    "quantile_range": [(25.0, 75.0), (10.0, 90.0)],
}
QuantileTransformer_params = {
    "n_quantiles": [10, 100, 1000],
    "output_distribution": ["uniform", "normal"],
    "ignore_implicit_zeros": [True, False],
    "subsample": [1e5],
}
param_grids = [
    StandardScaler_params,
    MinMaxScaler_params,
    KBinsDiscretizer_params,
    RobustScaler_params,
    QuantileTransformer_params,
]


models = [
    SVC(),
    RandomForestClassifier(),
    LogisticRegression(),
    GradientBoostingClassifier(),
    AdaBoostClassifier(),
    KNeighborsClassifier(),
    DecisionTreeClassifier(),
]

SVC_params = {
    "kernel": ["linear", "poly", "rbf", "sigmoid"],
    "C": [0.1, 1, 10],
    "degree": [1, 2, 3, 4, 5],
    "gamma": ["scale", "auto"],
}
RandomForestClassifier_params = {
    "n_estimators": [10, 100, 1000],
    "criterion": ["gini", "entropy"],
    "max_depth": [None, 3, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 3, 5],
    "max_features": ["auto", "sqrt", "log2"],
}
LogisticRegression_params = {
    "penalty": ["l1", "l2", "elasticnet", "none"],
    "C": [0.1, 1, 10],
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"],
    "max_iter": [100, 1000, 10000],
}
GradientBoostingClassifier_params = {
    "loss": ["deviance", "exponential"],
    "learning_rate": [0.1, 1, 10],
    "n_estimators": [10, 100, 1000],
    "criterion": ["friedman_mse", "mse", "mae"],
    "max_depth": [None, 3, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 3, 5],
    "max_features": ["auto", "sqrt", "log2"],
}
AdaBoostClassifier_params = {
    "n_estimators": [10, 100, 1000],
    "learning_rate": [0.1, 1, 10],
    "algorithm": ["SAMME", "SAMME.R"],
}
KNeighborsClassifier_params = {
    "n_neighbors": [3, 5, 10],
    "weights": ["uniform", "distance"],
    "algorithm": ["auto", "ball_tree", "kd_tree", "brute"],
    "leaf_size": [10, 30, 100],
    "p": [1, 2],
}
DecisionTreeClassifier_params = {
    "criterion": ["gini", "entropy"],
    "splitter": ["best", "random"],
    "max_depth": [None, 3, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 3, 5],
    "max_features": ["auto", "sqrt", "log2"],
}
model_params = [
    SVC_params,
    RandomForestClassifier_params,
    LogisticRegression_params,
    GradientBoostingClassifier_params,
    AdaBoostClassifier_params,
    KNeighborsClassifier_params,
    DecisionTreeClassifier_params,
]

def get_best_preprocessor_and_model(pre_processors, param_grids, models, model_params, X, y):
    best_score = 0
    best_preprocessor = None
    best_model = None
    best_model_params = None
    for preprocessor, param_grid in zip(pre_processors, param_grids):
        for model, params in zip(models, model_params):
            try:
                # Create a pipeline with the preprocessor and model
                pipeline = make_pipeline(preprocessor, model)

                # Train the model
                pipeline.fit(X, y)

                # Find the best parameters for both the feature extraction and the
                # classifier
                grid = GridSearchCV(
                    pipeline, params, error_score=0., n_jobs=-1, cv=5
                )
                grid.fit(X, y)

                # Update best score
                if grid.best_score_ > best_score:
                    best_score = grid.best_score_
                    best_preprocessor = preprocessor
                    best_model = model
                    best_model_params = grid.best_params_
            except Exception as e:
                print(e)
                print("---")
    print(
        "Best Score: {}".format(best_score)
    )
    print("Best Preprocessor: {}".format(best_preprocessor.__class__.__name__))
    print("Best Model: {}".format(best_model.__class__.__name__))
    print("Best Parameters: {}".format(best_model_params))
    print("---")
    return best_preprocessor, best_model, best_model_params

scoreboard = pd.DataFrame(
    columns=["Preprocessor", "Model", "Accuracy", "F1", "Precision", "Recall"]
)


def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average="weighted")
    precision = precision_score(y_test, y_pred, average="weighted")
    recall = recall_score(y_test, y_pred, average="weighted")
    return accuracy, f1, precision, recall


for preprocessor in pre_processors:
    for model in models:
        raise Exception("stop")
        pipeline = make_pipeline(preprocessor, model)

#         try:
#             # Create a pipeline with the preprocessor and model
#             pipeline = make_pipeline(preprocessor, model)

#             # Train the model
#             pipeline.fit(X_train, y_train)

#             accuracy, f1, precision, recall = evaluate_model(pipeline, X_test, y_test)
#         except Exception as e:
#             print(e)
#             print("---")
#             accuracy, f1, precision, recall = 0, 0, 0, 0
#         scoreboard = scoreboard.append(
#             {
#                 "Preprocessor": preprocessor.__class__.__name__,
#                 "Model": model.__class__.__name__,
#                 "Accuracy": accuracy,
#                 "F1": f1,
#                 "Precision": precision,
#                 "Recall": recall,
#             },
#             ignore_index=True,
#         )
# for metrics in ["Accuracy", "F1", "Precision", "Recall"]:
#     display(
#         pd.crosstab(
#             scoreboard["Preprocessor"],
#             scoreboard["Model"],
#             values=scoreboard[metrics],
#             aggfunc="mean",
#             margins=True,
#         )
#         .style.background_gradient(cmap="Blues")
#         .format("{:.1%}")
#     )

# %%
from sklearn.datasets import load_breast_cancer

# Load Breast Cancer data
cancer = load_breast_cancer()
data = pd.DataFrame(cancer.data, columns=cancer.feature_names)
target = pd.Series(cancer.target)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    data, target, test_size=0.3, random_state=0, shuffle=True
)

scoreboard = pd.DataFrame(
    columns=["Preprocessor", "Model", "Accuracy", "F1", "Precision", "Recall"]
)

for preprocessor in pre_processors:
    for model in models:
        try:
            # Create a pipeline with the preprocessor and model
            pipeline = make_pipeline(preprocessor, model)
            # Train the model
            pipeline.fit(X_train, y_train)
            accuracy, f1, precision, recall = evaluate_model(pipeline, X_test, y_test)
        except Exception as e:
            print(e)
            print("---")
            accuracy, f1, precision, recall = 0, 0, 0, 0
        scoreboard = scoreboard.append(
            {
                "Preprocessor": preprocessor.__class__.__name__,
                "Model": model.__class__.__name__,
                "Accuracy": accuracy,
                "F1": f1,
                "Precision": precision,
                "Recall": recall,
            },
            ignore_index=True,
        )

for metrics in ["Accuracy", "F1", "Precision", "Recall"]:
    display(
        pd.crosstab(
            scoreboard["Preprocessor"],
            scoreboard["Model"],
            values=scoreboard[metrics],
            aggfunc="mean",
            margins=True,
        )
        .style.background_gradient(cmap="Blues")
        .format("{:.1%}")
    )
# Out:
# <style type="text/css">
# #T_30406_row0_col0, #T_30406_row0_col2, #T_30406_row0_col3, #T_30406_row0_col4, #T_30406_row0_col5, #T_30406_row0_col6, #T_30406_row0_col7, #T_30406_row1_col2, #T_30406_row1_col4, #T_30406_row2_col1, #T_30406_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_30406_row0_col1, #T_30406_row1_col0, #T_30406_row1_col5, #T_30406_row2_col0, #T_30406_row2_col2, #T_30406_row2_col3, #T_30406_row2_col6, #T_30406_row3_col0, #T_30406_row3_col2, #T_30406_row3_col3, #T_30406_row3_col5, #T_30406_row3_col6, #T_30406_row3_col7, #T_30406_row4_col0, #T_30406_row4_col4, #T_30406_row4_col5, #T_30406_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_30406_row1_col1, #T_30406_row1_col6, #T_30406_row3_col1, #T_30406_row3_col4, #T_30406_row4_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_30406_row1_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_30406_row1_col7, #T_30406_row5_col3, #T_30406_row5_col6 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_30406_row2_col4, #T_30406_row4_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_30406_row2_col5 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_30406_row2_col7 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_30406_row4_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_30406_row5_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_30406_row5_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_30406_row5_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_30406_row5_col4 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_30406_row5_col5 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_30406_row5_col7 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_30406">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_30406_level0_col0" class="col_heading level0 col0" >AdaBoostClassifier</th>
#       <th id="T_30406_level0_col1" class="col_heading level0 col1" >DecisionTreeClassifier</th>
#       <th id="T_30406_level0_col2" class="col_heading level0 col2" >GradientBoostingClassifier</th>
#       <th id="T_30406_level0_col3" class="col_heading level0 col3" >KNeighborsClassifier</th>
#       <th id="T_30406_level0_col4" class="col_heading level0 col4" >LogisticRegression</th>
#       <th id="T_30406_level0_col5" class="col_heading level0 col5" >RandomForestClassifier</th>
#       <th id="T_30406_level0_col6" class="col_heading level0 col6" >SVC</th>
#       <th id="T_30406_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_30406_row5_col0" class="data row5 col0" >96.1%</td>
#       <td id="T_30406_row5_col1" class="data row5 col1" >91.9%</td>
#       <td id="T_30406_row5_col2" class="data row5 col2" >96.7%</td>
#       <td id="T_30406_row5_col3" class="data row5 col3" >95.8%</td>
#       <td id="T_30406_row5_col4" class="data row5 col4" >96.4%</td>
#       <td id="T_30406_row5_col5" class="data row5 col5" >96.8%</td>
#       <td id="T_30406_row5_col6" class="data row5 col6" >97.8%</td>
#       <td id="T_30406_row5_col7" class="data row5 col7" >95.9%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_64ccb_row0_col0, #T_64ccb_row0_col2, #T_64ccb_row0_col3, #T_64ccb_row0_col5, #T_64ccb_row0_col6, #T_64ccb_row0_col7, #T_64ccb_row1_col2, #T_64ccb_row1_col4, #T_64ccb_row2_col1, #T_64ccb_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_64ccb_row0_col1, #T_64ccb_row1_col0, #T_64ccb_row1_col5, #T_64ccb_row2_col0, #T_64ccb_row2_col2, #T_64ccb_row2_col3, #T_64ccb_row2_col6, #T_64ccb_row3_col0, #T_64ccb_row3_col2, #T_64ccb_row3_col5, #T_64ccb_row3_col7, #T_64ccb_row4_col0, #T_64ccb_row4_col4, #T_64ccb_row4_col5, #T_64ccb_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_64ccb_row0_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_64ccb_row1_col1 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_64ccb_row1_col3 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_64ccb_row1_col6, #T_64ccb_row4_col6 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_64ccb_row1_col7, #T_64ccb_row5_col6 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_64ccb_row2_col4 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_64ccb_row2_col5 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_64ccb_row2_col7 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_64ccb_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_64ccb_row3_col3 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_64ccb_row3_col4 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_64ccb_row3_col6 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_64ccb_row4_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_64ccb_row4_col3 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_64ccb_row5_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_64ccb_row5_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_64ccb_row5_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_64ccb_row5_col3 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_64ccb_row5_col4 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_64ccb_row5_col5 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_64ccb_row5_col7 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64ccb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_64ccb_level0_col0" class="col_heading level0 col0" >AdaBoostClassifier</th>
#       <th id="T_64ccb_level0_col1" class="col_heading level0 col1" >DecisionTreeClassifier</th>
#       <th id="T_64ccb_level0_col2" class="col_heading level0 col2" >GradientBoostingClassifier</th>
#       <th id="T_64ccb_level0_col3" class="col_heading level0 col3" >KNeighborsClassifier</th>
#       <th id="T_64ccb_level0_col4" class="col_heading level0 col4" >LogisticRegression</th>
#       <th id="T_64ccb_level0_col5" class="col_heading level0 col5" >RandomForestClassifier</th>
#       <th id="T_64ccb_level0_col6" class="col_heading level0 col6" >SVC</th>
#       <th id="T_64ccb_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64ccb_level0_row0" class="row_heading level0 row0" >KBinsDiscretizer</th>
#       <td id="T_64ccb_row0_col0" class="data row0 col0" >94.8%</td>
#       <td id="T_64ccb_row0_col1" class="data row0 col1" >93.0%</td>
#       <td id="T_64ccb_row0_col2" class="data row0 col2" >96.5%</td>
#       <td id="T_64ccb_row0_col3" class="data row0 col3" >94.7%</td>
#       <td id="T_64ccb_row0_col4" class="data row0 col4" >95.3%</td>
#       <td id="T_64ccb_row0_col5" class="data row0 col5" >94.2%</td>
#       <td id="T_64ccb_row0_col6" class="data row0 col6" >97.1%</td>
#       <td id="T_64ccb_row0_col7" class="data row0 col7" >95.1%</td>
#     </tr>
#     <tr>
#       <th id="T_64ccb_level0_row1" class="row_heading level0 row1" >MinMaxScaler</th>
#       <td id="T_64ccb_row1_col0" class="data row1 col0" >96.5%</td>
#       <td id="T_64ccb_row1_col1" class="data row1 col1" >91.9%</td>
#       <td id="T_64ccb_row1_col2" class="data row1 col2" >96.5%</td>
#       <td id="T_64ccb_row1_col3" class="data row1 col3" >95.3%</td>
#       <td id="T_64ccb_row1_col4" class="data row1 col4" >95.3%</td>
#       <td id="T_64ccb_row1_col5" class="data row1 col5" >97.7%</td>
#       <td id="T_64ccb_row1_col6" class="data row1 col6" >97.7%</td>
#       <td id="T_64ccb_row1_col7" class="data row1 col7" >95.8%</td>
#     </tr>
#     <tr>
#       <th id="T_64ccb_level0_row2" class="row_heading level0 row2" >QuantileTransformer</th>
#       <td id="T_64ccb_row2_col0" class="data row2 col0" >96.5%</td>
#       <td id="T_64ccb_row2_col1" class="data row2 col1" >90.7%</td>
#       <td id="T_64ccb_row2_col2" class="data row2 col2" >97.1%</td>
#       <td id="T_64ccb_row2_col3" class="data row2 col3" >96.5%</td>
#       <td id="T_64ccb_row2_col4" class="data row2 col4" >97.1%</td>
#       <td id="T_64ccb_row2_col5" class="data row2 col5" >97.1%</td>
#       <td id="T_64ccb_row2_col6" class="data row2 col6" >98.2%</td>
#       <td id="T_64ccb_row2_col7" class="data row2 col7" >96.2%</td>
#     </tr>
#     <tr>
#       <th id="T_64ccb_level0_row3" class="row_heading level0 row3" >RobustScaler</th>
#       <td id="T_64ccb_row3_col0" class="data row3 col0" >96.5%</td>
#       <td id="T_64ccb_row3_col1" class="data row3 col1" >91.9%</td>
#       <td id="T_64ccb_row3_col2" class="data row3 col2" >97.1%</td>
#       <td id="T_64ccb_row3_col3" class="data row3 col3" >96.5%</td>
#       <td id="T_64ccb_row3_col4" class="data row3 col4" >96.5%</td>
#       <td id="T_64ccb_row3_col5" class="data row3 col5" >97.7%</td>
#       <td id="T_64ccb_row3_col6" class="data row3 col6" >98.2%</td>
#       <td id="T_64ccb_row3_col7" class="data row3 col7" >96.3%</td>
#     </tr>
#     <tr>
#       <th id="T_64ccb_level0_row4" class="row_heading level0 row4" >StandardScaler</th>
#       <td id="T_64ccb_row4_col0" class="data row4 col0" >96.5%</td>
#       <td id="T_64ccb_row4_col1" class="data row4 col1" >92.5%</td>
#       <td id="T_64ccb_row4_col2" class="data row4 col2" >96.5%</td>
#       <td id="T_64ccb_row4_col3" class="data row4 col3" >95.9%</td>
#       <td id="T_64ccb_row4_col4" class="data row4 col4" >97.7%</td>
#       <td id="T_64ccb_row4_col5" class="data row4 col5" >97.7%</td>
#       <td id="T_64ccb_row4_col6" class="data row4 col6" >97.7%</td>
#       <td id="T_64ccb_row4_col7" class="data row4 col7" >96.3%</td>
#     </tr>
#     <tr>
#       <th id="T_64ccb_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_64ccb_row5_col0" class="data row5 col0" >96.2%</td>
#       <td id="T_64ccb_row5_col1" class="data row5 col1" >92.0%</td>
#       <td id="T_64ccb_row5_col2" class="data row5 col2" >96.7%</td>
#       <td id="T_64ccb_row5_col3" class="data row5 col3" >95.8%</td>
#       <td id="T_64ccb_row5_col4" class="data row5 col4" >96.4%</td>
#       <td id="T_64ccb_row5_col5" class="data row5 col5" >96.8%</td>
#       <td id="T_64ccb_row5_col6" class="data row5 col6" >97.8%</td>
#       <td id="T_64ccb_row5_col7" class="data row5 col7" >95.9%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bbfb8_row0_col0, #T_bbfb8_row0_col2, #T_bbfb8_row0_col3, #T_bbfb8_row0_col4, #T_bbfb8_row0_col5, #T_bbfb8_row0_col6, #T_bbfb8_row0_col7, #T_bbfb8_row1_col2, #T_bbfb8_row2_col1, #T_bbfb8_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bbfb8_row0_col1, #T_bbfb8_row1_col0, #T_bbfb8_row1_col5, #T_bbfb8_row2_col0, #T_bbfb8_row2_col2, #T_bbfb8_row2_col6, #T_bbfb8_row3_col0, #T_bbfb8_row3_col2, #T_bbfb8_row3_col3, #T_bbfb8_row3_col5, #T_bbfb8_row4_col0, #T_bbfb8_row4_col4, #T_bbfb8_row4_col5, #T_bbfb8_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bbfb8_row1_col1 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_bbfb8_row1_col3 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_bbfb8_row1_col4 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_bbfb8_row1_col6, #T_bbfb8_row4_col6 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_bbfb8_row1_col7 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_bbfb8_row2_col3, #T_bbfb8_row3_col6 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_bbfb8_row2_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_bbfb8_row2_col5 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_bbfb8_row2_col7 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_bbfb8_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_bbfb8_row3_col4 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_bbfb8_row3_col7 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_bbfb8_row4_col1 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_bbfb8_row4_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_bbfb8_row5_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_bbfb8_row5_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_bbfb8_row5_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_bbfb8_row5_col3 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_bbfb8_row5_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_bbfb8_row5_col5 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_bbfb8_row5_col6 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_bbfb8_row5_col7 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bbfb8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_bbfb8_level0_col0" class="col_heading level0 col0" >AdaBoostClassifier</th>
#       <th id="T_bbfb8_level0_col1" class="col_heading level0 col1" >DecisionTreeClassifier</th>
#       <th id="T_bbfb8_level0_col2" class="col_heading level0 col2" >GradientBoostingClassifier</th>
#       <th id="T_bbfb8_level0_col3" class="col_heading level0 col3" >KNeighborsClassifier</th>
#       <th id="T_bbfb8_level0_col4" class="col_heading level0 col4" >LogisticRegression</th>
#       <th id="T_bbfb8_level0_col5" class="col_heading level0 col5" >RandomForestClassifier</th>
#       <th id="T_bbfb8_level0_col6" class="col_heading level0 col6" >SVC</th>
#       <th id="T_bbfb8_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbfb8_level0_row0" class="row_heading level0 row0" >KBinsDiscretizer</th>
#       <td id="T_bbfb8_row0_col0" class="data row0 col0" >95.2%</td>
#       <td id="T_bbfb8_row0_col1" class="data row0 col1" >93.3%</td>
#       <td id="T_bbfb8_row0_col2" class="data row0 col2" >96.5%</td>
#       <td id="T_bbfb8_row0_col3" class="data row0 col3" >94.7%</td>
#       <td id="T_bbfb8_row0_col4" class="data row0 col4" >95.3%</td>
#       <td id="T_bbfb8_row0_col5" class="data row0 col5" >94.2%</td>
#       <td id="T_bbfb8_row0_col6" class="data row0 col6" >97.1%</td>
#       <td id="T_bbfb8_row0_col7" class="data row0 col7" >95.2%</td>
#     </tr>
#     <tr>
#       <th id="T_bbfb8_level0_row1" class="row_heading level0 row1" >MinMaxScaler</th>
#       <td id="T_bbfb8_row1_col0" class="data row1 col0" >96.5%</td>
#       <td id="T_bbfb8_row1_col1" class="data row1 col1" >92.4%</td>
#       <td id="T_bbfb8_row1_col2" class="data row1 col2" >96.5%</td>
#       <td id="T_bbfb8_row1_col3" class="data row1 col3" >95.4%</td>
#       <td id="T_bbfb8_row1_col4" class="data row1 col4" >95.5%</td>
#       <td id="T_bbfb8_row1_col5" class="data row1 col5" >97.7%</td>
#       <td id="T_bbfb8_row1_col6" class="data row1 col6" >97.7%</td>
#       <td id="T_bbfb8_row1_col7" class="data row1 col7" >96.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bbfb8_level0_row2" class="row_heading level0 row2" >QuantileTransformer</th>
#       <td id="T_bbfb8_row2_col0" class="data row2 col0" >96.5%</td>
#       <td id="T_bbfb8_row2_col1" class="data row2 col1" >91.0%</td>
#       <td id="T_bbfb8_row2_col2" class="data row2 col2" >97.1%</td>
#       <td id="T_bbfb8_row2_col3" class="data row2 col3" >96.5%</td>
#       <td id="T_bbfb8_row2_col4" class="data row2 col4" >97.1%</td>
#       <td id="T_bbfb8_row2_col5" class="data row2 col5" >97.1%</td>
#       <td id="T_bbfb8_row2_col6" class="data row2 col6" >98.3%</td>
#       <td id="T_bbfb8_row2_col7" class="data row2 col7" >96.2%</td>
#     </tr>
#     <tr>
#       <th id="T_bbfb8_level0_row3" class="row_heading level0 row3" >RobustScaler</th>
#       <td id="T_bbfb8_row3_col0" class="data row3 col0" >96.5%</td>
#       <td id="T_bbfb8_row3_col1" class="data row3 col1" >92.2%</td>
#       <td id="T_bbfb8_row3_col2" class="data row3 col2" >97.1%</td>
#       <td id="T_bbfb8_row3_col3" class="data row3 col3" >96.6%</td>
#       <td id="T_bbfb8_row3_col4" class="data row3 col4" >96.5%</td>
#       <td id="T_bbfb8_row3_col5" class="data row3 col5" >97.7%</td>
#       <td id="T_bbfb8_row3_col6" class="data row3 col6" >98.2%</td>
#       <td id="T_bbfb8_row3_col7" class="data row3 col7" >96.4%</td>
#     </tr>
#     <tr>
#       <th id="T_bbfb8_level0_row4" class="row_heading level0 row4" >StandardScaler</th>
#       <td id="T_bbfb8_row4_col0" class="data row4 col0" >96.5%</td>
#       <td id="T_bbfb8_row4_col1" class="data row4 col1" >92.9%</td>
#       <td id="T_bbfb8_row4_col2" class="data row4 col2" >96.5%</td>
#       <td id="T_bbfb8_row4_col3" class="data row4 col3" >96.0%</td>
#       <td id="T_bbfb8_row4_col4" class="data row4 col4" >97.7%</td>
#       <td id="T_bbfb8_row4_col5" class="data row4 col5" >97.7%</td>
#       <td id="T_bbfb8_row4_col6" class="data row4 col6" >97.7%</td>
#       <td id="T_bbfb8_row4_col7" class="data row4 col7" >96.4%</td>
#     </tr>
#     <tr>
#       <th id="T_bbfb8_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_bbfb8_row5_col0" class="data row5 col0" >96.3%</td>
#       <td id="T_bbfb8_row5_col1" class="data row5 col1" >92.4%</td>
#       <td id="T_bbfb8_row5_col2" class="data row5 col2" >96.8%</td>
#       <td id="T_bbfb8_row5_col3" class="data row5 col3" >95.8%</td>
#       <td id="T_bbfb8_row5_col4" class="data row5 col4" >96.4%</td>
#       <td id="T_bbfb8_row5_col5" class="data row5 col5" >96.9%</td>
#       <td id="T_bbfb8_row5_col6" class="data row5 col6" >97.8%</td>
#       <td id="T_bbfb8_row5_col7" class="data row5 col7" >96.0%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_56add_row0_col0, #T_56add_row0_col2, #T_56add_row0_col3, #T_56add_row0_col4, #T_56add_row0_col5, #T_56add_row0_col6, #T_56add_row0_col7, #T_56add_row1_col2, #T_56add_row1_col4, #T_56add_row2_col1, #T_56add_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_56add_row0_col1, #T_56add_row1_col0, #T_56add_row1_col5, #T_56add_row2_col0, #T_56add_row2_col2, #T_56add_row2_col3, #T_56add_row2_col6, #T_56add_row3_col0, #T_56add_row3_col2, #T_56add_row3_col3, #T_56add_row3_col5, #T_56add_row3_col6, #T_56add_row3_col7, #T_56add_row4_col0, #T_56add_row4_col4, #T_56add_row4_col5, #T_56add_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_56add_row1_col1, #T_56add_row1_col6, #T_56add_row3_col1, #T_56add_row3_col4, #T_56add_row4_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_56add_row1_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_56add_row1_col7, #T_56add_row5_col3, #T_56add_row5_col6 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_56add_row2_col4, #T_56add_row4_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_56add_row2_col5 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_56add_row2_col7 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_56add_row4_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_56add_row5_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_56add_row5_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_56add_row5_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_56add_row5_col4 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_56add_row5_col5 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_56add_row5_col7 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_56add">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_56add_level0_col0" class="col_heading level0 col0" >AdaBoostClassifier</th>
#       <th id="T_56add_level0_col1" class="col_heading level0 col1" >DecisionTreeClassifier</th>
#       <th id="T_56add_level0_col2" class="col_heading level0 col2" >GradientBoostingClassifier</th>
#       <th id="T_56add_level0_col3" class="col_heading level0 col3" >KNeighborsClassifier</th>
#       <th id="T_56add_level0_col4" class="col_heading level0 col4" >LogisticRegression</th>
#       <th id="T_56add_level0_col5" class="col_heading level0 col5" >RandomForestClassifier</th>
#       <th id="T_56add_level0_col6" class="col_heading level0 col6" >SVC</th>
#       <th id="T_56add_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56add_level0_row0" class="row_heading level0 row0" >KBinsDiscretizer</th>
#       <td id="T_56add_row0_col0" class="data row0 col0" >94.7%</td>
#       <td id="T_56add_row0_col1" class="data row0 col1" >93.0%</td>
#       <td id="T_56add_row0_col2" class="data row0 col2" >96.5%</td>
#       <td id="T_56add_row0_col3" class="data row0 col3" >94.7%</td>
#       <td id="T_56add_row0_col4" class="data row0 col4" >95.3%</td>
#       <td id="T_56add_row0_col5" class="data row0 col5" >94.2%</td>
#       <td id="T_56add_row0_col6" class="data row0 col6" >97.1%</td>
#       <td id="T_56add_row0_col7" class="data row0 col7" >95.1%</td>
#     </tr>
#     <tr>
#       <th id="T_56add_level0_row1" class="row_heading level0 row1" >MinMaxScaler</th>
#       <td id="T_56add_row1_col0" class="data row1 col0" >96.5%</td>
#       <td id="T_56add_row1_col1" class="data row1 col1" >91.8%</td>
#       <td id="T_56add_row1_col2" class="data row1 col2" >96.5%</td>
#       <td id="T_56add_row1_col3" class="data row1 col3" >95.3%</td>
#       <td id="T_56add_row1_col4" class="data row1 col4" >95.3%</td>
#       <td id="T_56add_row1_col5" class="data row1 col5" >97.7%</td>
#       <td id="T_56add_row1_col6" class="data row1 col6" >97.7%</td>
#       <td id="T_56add_row1_col7" class="data row1 col7" >95.8%</td>
#     </tr>
#     <tr>
#       <th id="T_56add_level0_row2" class="row_heading level0 row2" >QuantileTransformer</th>
#       <td id="T_56add_row2_col0" class="data row2 col0" >96.5%</td>
#       <td id="T_56add_row2_col1" class="data row2 col1" >90.6%</td>
#       <td id="T_56add_row2_col2" class="data row2 col2" >97.1%</td>
#       <td id="T_56add_row2_col3" class="data row2 col3" >96.5%</td>
#       <td id="T_56add_row2_col4" class="data row2 col4" >97.1%</td>
#       <td id="T_56add_row2_col5" class="data row2 col5" >97.1%</td>
#       <td id="T_56add_row2_col6" class="data row2 col6" >98.2%</td>
#       <td id="T_56add_row2_col7" class="data row2 col7" >96.2%</td>
#     </tr>
#     <tr>
#       <th id="T_56add_level0_row3" class="row_heading level0 row3" >RobustScaler</th>
#       <td id="T_56add_row3_col0" class="data row3 col0" >96.5%</td>
#       <td id="T_56add_row3_col1" class="data row3 col1" >91.8%</td>
#       <td id="T_56add_row3_col2" class="data row3 col2" >97.1%</td>
#       <td id="T_56add_row3_col3" class="data row3 col3" >96.5%</td>
#       <td id="T_56add_row3_col4" class="data row3 col4" >96.5%</td>
#       <td id="T_56add_row3_col5" class="data row3 col5" >97.7%</td>
#       <td id="T_56add_row3_col6" class="data row3 col6" >98.2%</td>
#       <td id="T_56add_row3_col7" class="data row3 col7" >96.3%</td>
#     </tr>
#     <tr>
#       <th id="T_56add_level0_row4" class="row_heading level0 row4" >StandardScaler</th>
#       <td id="T_56add_row4_col0" class="data row4 col0" >96.5%</td>
#       <td id="T_56add_row4_col1" class="data row4 col1" >92.4%</td>
#       <td id="T_56add_row4_col2" class="data row4 col2" >96.5%</td>
#       <td id="T_56add_row4_col3" class="data row4 col3" >95.9%</td>
#       <td id="T_56add_row4_col4" class="data row4 col4" >97.7%</td>
#       <td id="T_56add_row4_col5" class="data row4 col5" >97.7%</td>
#       <td id="T_56add_row4_col6" class="data row4 col6" >97.7%</td>
#       <td id="T_56add_row4_col7" class="data row4 col7" >96.3%</td>
#     </tr>
#     <tr>
#       <th id="T_56add_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_56add_row5_col0" class="data row5 col0" >96.1%</td>
#       <td id="T_56add_row5_col1" class="data row5 col1" >91.9%</td>
#       <td id="T_56add_row5_col2" class="data row5 col2" >96.7%</td>
#       <td id="T_56add_row5_col3" class="data row5 col3" >95.8%</td>
#       <td id="T_56add_row5_col4" class="data row5 col4" >96.4%</td>
#       <td id="T_56add_row5_col5" class="data row5 col5" >96.8%</td>
#       <td id="T_56add_row5_col6" class="data row5 col6" >97.8%</td>
#       <td id="T_56add_row5_col7" class="data row5 col7" >95.9%</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.datasets import load_wine

# Load Wine data
wine = load_wine()
data = pd.DataFrame(wine.data, columns=wine.feature_names)
target = pd.Series(wine.target)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    data, target, test_size=0.1, random_state=0, shuffle=True
)

scoreboard = pd.DataFrame(
    columns=["Preprocessor", "Model", "Accuracy", "F1", "Precision", "Recall"]
)

for preprocessor in pre_processors:
    for model in models:
        try:
            # Create a pipeline with the preprocessor and model
            pipeline = make_pipeline(preprocessor, model)
            # Train the model
            pipeline.fit(X_train, y_train)
            accuracy, f1, precision, recall = evaluate_model(pipeline, X_test, y_test)
        except Exception as e:
            print(e)
            print("---")
            accuracy, f1, precision, recall = 0, 0, 0, 0
        scoreboard = scoreboard.append(
            {
                "Preprocessor": preprocessor.__class__.__name__,
                "Model": model.__class__.__name__,
                "Accuracy": accuracy,
                "F1": f1,
                "Precision": precision,
                "Recall": recall,
            },
            ignore_index=True,
        )

for metrics in ["Accuracy", "F1", "Precision", "Recall"]:
    display(
        pd.crosstab(
            scoreboard["Preprocessor"],
            scoreboard["Model"],
            values=scoreboard[metrics],
            aggfunc="mean",
            margins=True,
        )
        .style.background_gradient(cmap="Blues")
        .format("{:.1%}")
    )
# Out:
# <style type="text/css">
# #T_d888d_row0_col0, #T_d888d_row0_col1, #T_d888d_row0_col3, #T_d888d_row0_col4, #T_d888d_row0_col5, #T_d888d_row0_col6, #T_d888d_row1_col0, #T_d888d_row1_col2, #T_d888d_row1_col3, #T_d888d_row1_col4, #T_d888d_row1_col5, #T_d888d_row1_col6, #T_d888d_row2_col0, #T_d888d_row2_col1, #T_d888d_row2_col2, #T_d888d_row2_col3, #T_d888d_row2_col4, #T_d888d_row2_col5, #T_d888d_row2_col6, #T_d888d_row2_col7, #T_d888d_row3_col0, #T_d888d_row3_col2, #T_d888d_row3_col3, #T_d888d_row3_col4, #T_d888d_row3_col5, #T_d888d_row3_col6, #T_d888d_row4_col0, #T_d888d_row4_col1, #T_d888d_row4_col2, #T_d888d_row4_col3, #T_d888d_row4_col4, #T_d888d_row4_col5, #T_d888d_row4_col6, #T_d888d_row4_col7, #T_d888d_row5_col0, #T_d888d_row5_col3, #T_d888d_row5_col4, #T_d888d_row5_col5, #T_d888d_row5_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d888d_row0_col2, #T_d888d_row0_col7, #T_d888d_row1_col1, #T_d888d_row1_col7, #T_d888d_row3_col1, #T_d888d_row3_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d888d_row5_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_d888d_row5_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_d888d_row5_col7 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d888d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_d888d_level0_col0" class="col_heading level0 col0" >AdaBoostClassifier</th>
#       <th id="T_d888d_level0_col1" class="col_heading level0 col1" >DecisionTreeClassifier</th>
#       <th id="T_d888d_level0_col2" class="col_heading level0 col2" >GradientBoostingClassifier</th>
#       <th id="T_d888d_level0_col3" class="col_heading level0 col3" >KNeighborsClassifier</th>
#       <th id="T_d888d_level0_col4" class="col_heading level0 col4" >LogisticRegression</th>
#       <th id="T_d888d_level0_col5" class="col_heading level0 col5" >RandomForestClassifier</th>
#       <th id="T_d888d_level0_col6" class="col_heading level0 col6" >SVC</th>
#       <th id="T_d888d_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d888d_level0_row0" class="row_heading level0 row0" >KBinsDiscretizer</th>
#       <td id="T_d888d_row0_col0" class="data row0 col0" >83.3%</td>
#       <td id="T_d888d_row0_col1" class="data row0 col1" >94.4%</td>
#       <td id="T_d888d_row0_col2" class="data row0 col2" >100.0%</td>
#       <td id="T_d888d_row0_col3" class="data row0 col3" >100.0%</td>
#       <td id="T_d888d_row0_col4" class="data row0 col4" >100.0%</td>
#       <td id="T_d888d_row0_col5" class="data row0 col5" >100.0%</td>
#       <td id="T_d888d_row0_col6" class="data row0 col6" >100.0%</td>
#       <td id="T_d888d_row0_col7" class="data row0 col7" >96.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d888d_level0_row1" class="row_heading level0 row1" >MinMaxScaler</th>
#       <td id="T_d888d_row1_col0" class="data row1 col0" >83.3%</td>
#       <td id="T_d888d_row1_col1" class="data row1 col1" >100.0%</td>
#       <td id="T_d888d_row1_col2" class="data row1 col2" >94.4%</td>
#       <td id="T_d888d_row1_col3" class="data row1 col3" >100.0%</td>
#       <td id="T_d888d_row1_col4" class="data row1 col4" >100.0%</td>
#       <td id="T_d888d_row1_col5" class="data row1 col5" >100.0%</td>
#       <td id="T_d888d_row1_col6" class="data row1 col6" >100.0%</td>
#       <td id="T_d888d_row1_col7" class="data row1 col7" >96.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d888d_level0_row2" class="row_heading level0 row2" >QuantileTransformer</th>
#       <td id="T_d888d_row2_col0" class="data row2 col0" >83.3%</td>
#       <td id="T_d888d_row2_col1" class="data row2 col1" >94.4%</td>
#       <td id="T_d888d_row2_col2" class="data row2 col2" >94.4%</td>
#       <td id="T_d888d_row2_col3" class="data row2 col3" >100.0%</td>
#       <td id="T_d888d_row2_col4" class="data row2 col4" >100.0%</td>
#       <td id="T_d888d_row2_col5" class="data row2 col5" >100.0%</td>
#       <td id="T_d888d_row2_col6" class="data row2 col6" >100.0%</td>
#       <td id="T_d888d_row2_col7" class="data row2 col7" >96.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d888d_level0_row3" class="row_heading level0 row3" >RobustScaler</th>
#       <td id="T_d888d_row3_col0" class="data row3 col0" >83.3%</td>
#       <td id="T_d888d_row3_col1" class="data row3 col1" >100.0%</td>
#       <td id="T_d888d_row3_col2" class="data row3 col2" >94.4%</td>
#       <td id="T_d888d_row3_col3" class="data row3 col3" >100.0%</td>
#       <td id="T_d888d_row3_col4" class="data row3 col4" >100.0%</td>
#       <td id="T_d888d_row3_col5" class="data row3 col5" >100.0%</td>
#       <td id="T_d888d_row3_col6" class="data row3 col6" >100.0%</td>
#       <td id="T_d888d_row3_col7" class="data row3 col7" >96.8%</td>
#     </tr>
#     <tr>
#       <th id="T_d888d_level0_row4" class="row_heading level0 row4" >StandardScaler</th>
#       <td id="T_d888d_row4_col0" class="data row4 col0" >83.3%</td>
#       <td id="T_d888d_row4_col1" class="data row4 col1" >94.4%</td>
#       <td id="T_d888d_row4_col2" class="data row4 col2" >94.4%</td>
#       <td id="T_d888d_row4_col3" class="data row4 col3" >100.0%</td>
#       <td id="T_d888d_row4_col4" class="data row4 col4" >100.0%</td>
#       <td id="T_d888d_row4_col5" class="data row4 col5" >100.0%</td>
#       <td id="T_d888d_row4_col6" class="data row4 col6" >100.0%</td>
#       <td id="T_d888d_row4_col7" class="data row4 col7" >96.0%</td>
#     </tr>
#     <tr>
#       <th id="T_d888d_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_d888d_row5_col0" class="data row5 col0" >83.3%</td>
#       <td id="T_d888d_row5_col1" class="data row5 col1" >96.7%</td>
#       <td id="T_d888d_row5_col2" class="data row5 col2" >95.6%</td>
#       <td id="T_d888d_row5_col3" class="data row5 col3" >100.0%</td>
#       <td id="T_d888d_row5_col4" class="data row5 col4" >100.0%</td>
#       <td id="T_d888d_row5_col5" class="data row5 col5" >100.0%</td>
#       <td id="T_d888d_row5_col6" class="data row5 col6" >100.0%</td>
#       <td id="T_d888d_row5_col7" class="data row5 col7" >96.5%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_29b22_row0_col0, #T_29b22_row0_col1, #T_29b22_row0_col3, #T_29b22_row0_col4, #T_29b22_row0_col5, #T_29b22_row0_col6, #T_29b22_row1_col0, #T_29b22_row1_col2, #T_29b22_row1_col3, #T_29b22_row1_col4, #T_29b22_row1_col5, #T_29b22_row1_col6, #T_29b22_row2_col0, #T_29b22_row2_col1, #T_29b22_row2_col2, #T_29b22_row2_col3, #T_29b22_row2_col4, #T_29b22_row2_col5, #T_29b22_row2_col6, #T_29b22_row2_col7, #T_29b22_row3_col0, #T_29b22_row3_col2, #T_29b22_row3_col3, #T_29b22_row3_col4, #T_29b22_row3_col5, #T_29b22_row3_col6, #T_29b22_row4_col0, #T_29b22_row4_col1, #T_29b22_row4_col2, #T_29b22_row4_col3, #T_29b22_row4_col4, #T_29b22_row4_col5, #T_29b22_row4_col6, #T_29b22_row4_col7, #T_29b22_row5_col3, #T_29b22_row5_col4, #T_29b22_row5_col5, #T_29b22_row5_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_29b22_row0_col2, #T_29b22_row0_col7, #T_29b22_row1_col1, #T_29b22_row1_col7, #T_29b22_row3_col1, #T_29b22_row3_col7, #T_29b22_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_29b22_row5_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_29b22_row5_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_29b22_row5_col7 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_29b22">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_29b22_level0_col0" class="col_heading level0 col0" >AdaBoostClassifier</th>
#       <th id="T_29b22_level0_col1" class="col_heading level0 col1" >DecisionTreeClassifier</th>
#       <th id="T_29b22_level0_col2" class="col_heading level0 col2" >GradientBoostingClassifier</th>
#       <th id="T_29b22_level0_col3" class="col_heading level0 col3" >KNeighborsClassifier</th>
#       <th id="T_29b22_level0_col4" class="col_heading level0 col4" >LogisticRegression</th>
#       <th id="T_29b22_level0_col5" class="col_heading level0 col5" >RandomForestClassifier</th>
#       <th id="T_29b22_level0_col6" class="col_heading level0 col6" >SVC</th>
#       <th id="T_29b22_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29b22_level0_row0" class="row_heading level0 row0" >KBinsDiscretizer</th>
#       <td id="T_29b22_row0_col0" class="data row0 col0" >82.7%</td>
#       <td id="T_29b22_row0_col1" class="data row0 col1" >94.4%</td>
#       <td id="T_29b22_row0_col2" class="data row0 col2" >100.0%</td>
#       <td id="T_29b22_row0_col3" class="data row0 col3" >100.0%</td>
#       <td id="T_29b22_row0_col4" class="data row0 col4" >100.0%</td>
#       <td id="T_29b22_row0_col5" class="data row0 col5" >100.0%</td>
#       <td id="T_29b22_row0_col6" class="data row0 col6" >100.0%</td>
</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6aa93_row0_col0, #T_6aa93_row0_col1, #T_6aa93_row0_col3, #T_6aa93_row0_col4, #T_6aa93_row0_col5, #T_6aa93_row0_col6, #T_6aa93_row1_col0, #T_6aa93_row1_col2, #T_6aa93_row1_col3, #T_6aa93_row1_col4, #T_6aa93_row1_col5, #T_6aa93_row1_col6, #T_6aa93_row2_col0, #T_6aa93_row2_col1, #T_6aa93_row2_col2, #T_6aa93_row2_col3, #T_6aa93_row2_col4, #T_6aa93_row2_col5, #T_6aa93_row2_col6, #T_6aa93_row2_col7, #T_6aa93_row3_col0, #T_6aa93_row3_col2, #T_6aa93_row3_col3, #T_6aa93_row3_col4, #T_6aa93_row3_col5, #T_6aa93_row3_col6, #T_6aa93_row4_col0, #T_6aa93_row4_col1, #T_6aa93_row4_col2, #T_6aa93_row4_col3, #T_6aa93_row4_col4, #T_6aa93_row4_col5, #T_6aa93_row4_col6, #T_6aa93_row4_col7, #T_6aa93_row5_col3, #T_6aa93_row5_col4, #T_6aa93_row5_col5, #T_6aa93_row5_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6aa93_row0_col2, #T_6aa93_row0_col7, #T_6aa93_row1_col1, #T_6aa93_row1_col7, #T_6aa93_row3_col1, #T_6aa93_row3_col7, #T_6aa93_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6aa93_row5_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_6aa93_row5_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_6aa93_row5_col7 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6aa93">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_6aa93_level0_col0" class="col_heading level0 col0" >AdaBoostClassifier</th>
#       <th id="T_6aa93_level0_col1" class="col_heading level0 col1" >DecisionTreeClassifier</th>
#       <th id="T_6aa93_level0_col2" class="col_heading level0 col2" >GradientBoostingClassifier</th>
#       <th id="T_6aa93_level0_col3" class="col_heading level0 col3" >KNeighborsClassifier</th>
#       <th id="T_6aa93_level0_col4" class="col_heading level0 col4" >LogisticRegression</th>
#       <th id="T_6aa93_level0_col5" class="col_heading level0 col5" >RandomForestClassifier</th>
#       <th id="T_6aa93_level0_col6" class="col_heading level0 col6" >SVC</th>
#       <th id="T_6aa93_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa93_level0_row0" class="row_heading level0 row0" >KBinsDiscretizer</th>
#       <td id="T_6aa93_row0_col0" class="data row0 col0" >88.9%</td>
#       <td id="T_6aa93_row0_col1" class="data row0 col1" >95.2%</td>
#       <td id="T_6aa93_row0_col2" class="data row0 col2" >100.0%</td>
#       <td id="T_6aa93_row0_col3" class="data row0 col3" >100.0%</td>
#       <td id="T_6aa93_row0_col4" class="data row0 col4" >100.0%</td>
#       <td id="T_6aa93_row0_col5" class="data row0 col5" >100.0%</td>
#       <td id="T_6aa93_row0_col6" class="data row0 col6" >100.0%</td>
#       <td id="T_6aa93_row0_col7" class="data row0 col7" >97.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6a
</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8cfbb_row0_col0, #T_8cfbb_row0_col1, #T_8cfbb_row0_col3, #T_8cfbb_row0_col4, #T_8cfbb_row0_col5, #T_8cfbb_row0_col6, #T_8cfbb_row1_col0, #T_8cfbb_row1_col2, #T_8cfbb_row1_col3, #T_8cfbb_row1_col4, #T_8cfbb_row1_col5, #T_8cfbb_row1_col6, #T_8cfbb_row2_col0, #T_8cfbb_row2_col1, #T_8cfbb_row2_col2, #T_8cfbb_row2_col3, #T_8cfbb_row2_col4, #T_8cfbb_row2_col5, #T_8cfbb_row2_col6, #T_8cfbb_row2_col7, #T_8cfbb_row3_col0, #T_8cfbb_row3_col2, #T_8cfbb_row3_col3, #T_8cfbb_row3_col4, #T_8cfbb_row3_col5, #T_8cfbb_row3_col6, #T_8cfbb_row4_col0, #T_8cfbb_row4_col1, #T_8cfbb_row4_col2, #T_8cfbb_row4_col3, #T_8cfbb_row4_col4, #T_8cfbb_row4_col5, #T_8cfbb_row4_col6, #T_8cfbb_row4_col7, #T_8cfbb_row5_col0, #T_8cfbb_row5_col3, #T_8cfbb_row5_col4, #T_8cfbb_row5_col5, #T_8cfbb_row5_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8cfbb_row0_col2, #T_8cfbb_row0_col7, #T_8cfbb_row1_col1, #T_8cfbb_row1_col7, #T_8cfbb_row3_col1, #T_8cfbb_row3_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8cfbb_row5_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_8cfbb_row5_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_8cfbb_row5_col7 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8cfbb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th id="T_8cfbb_level0_col0" class="col_heading level0 col0" >AdaBoostClassifier</th>
#       <th id="T_8cfbb_level0_col1" class="col_heading level0 col1" >DecisionTreeClassifier</th>
#       <th id="T_8cfbb_level0_col2" class="col_heading level0 col2" >GradientBoostingClassifier</th>
#       <th id="T_8cfbb_level0_col3" class="col_heading level0 col3" >KNeighborsClassifier</th>
#       <th id="T_8cfbb_level0_col4" class="col_heading level0 col4" >LogisticRegression</th>
#       <th id="T_8cfbb_level0_col5" class="col_heading level0 col5" >RandomForestClassifier</th>
#       <th id="T_8cfbb_level0_col6" class="col_heading level0 col6" >SVC</th>
#       <th id="T_8cfbb_level0_col7" class="col_heading level0 col7" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Preprocessor</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cfbb_level0_row0" class="row_heading level0 row0" >KBinsDiscretizer</th>
#       <td id="T_8cfbb_row0_col0" class="data row0 col0" >83.3%</td>
#       <td id="T_8cfbb_row0_col1" class="data row0 col1" >94.4%</td>
#       <td id="T_8cfbb_row0_col2" class="data row0 col2" >100.0%</td>
#       <td id="T_8cfbb_row0_col3" class="data row0 col3" >100.0%</td>
#       <td id="T_8cfbb_row0_col4" class="data row0 col4" >100.0%</td>
#       <td id="T_8cfbb_row0_col5" class="data row0 col5" >100.0%</td>
#       <td id="T_8cfbb_row0_col6" class="data row0 col6" >100.0%</td>
#       <td id="T_8cfbb_row0_col7" class="data row0 col7" >96.8%</td>
#     </tr>
#     <tr>
#       <th id="T_8cfbb_level0_row1" class="row_heading level0 row1" >MinMaxScaler</th>
#       <td id="T_8cfbb_row1_col0" class="data row1 col0" >83.3%</td>
#       <td id="T_8cfbb_row1_col1" class="data row1 col1" >100.0%</td>
#       <td id="T_8cfbb_row1_col2" class="data row1 col2" >94.4%</td>
#       <td id="T_8cfbb_row1_col3" class="data row1 col3" >100.0%</td>
